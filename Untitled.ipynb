# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("predictive_maintenance.csv")

# %%
data.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
data.isnull().sum()
# Out:
# UDI                        0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Target                     0
# Failure Type               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
data['Type'] = le.fit_transform(data['Type'])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled = scaler.fit_transform(data[['Air temperature [K]', 'Process temperature [K]', 'Torque [Nm]', 'Rotational speed [rpm]']])

# %%
import numpy as np

Q1 = data['Torque [Nm]'].quantile(0.25)
Q3 = data['Torque [Nm]'].quantile(0.75)
IQR = Q3 - Q1

data = data[~((data['Torque [Nm]'] < (Q1 - 1.5 * IQR)) | (data['Torque [Nm]'] > (Q3 + 1.5 * IQR)))]

# %%
data.head()
# Out:
#    UDI Product ID  Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860     2                298.1                    308.6
# 1    2     L47181     1                298.2                    308.7
# 2    3     L47182     1                298.1                    308.5
# 3    4     L47183     1                298.2                    308.6
# 4    5     L47184     1                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
data['temp_diff'] = data['Process temperature [K]'] - data['Air temperature [K]']
data['torque_per_speed'] = data['Torque [Nm]'] / data['Rotational speed [rpm]']
# Out:
# C:\Users\Jai  Malhotra\AppData\Local\Temp\ipykernel_9820\3104727066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['temp_diff'] = data['Process temperature [K]'] - data['Air temperature [K]']
# C:\Users\Jai  Malhotra\AppData\Local\Temp\ipykernel_9820\3104727066.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['torque_per_speed'] = data['Torque [Nm]'] / data['Rotational speed [rpm]']

# %%
data.head()
# Out:
#    UDI Product ID  Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860     2                298.1                    308.6
# 1    2     L47181     1                298.2                    308.7
# 2    3     L47182     1                298.1                    308.5
# 3    4     L47183     1                298.2                    308.6
# 4    5     L47184     1                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type  \
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure
#
#    temp_diff  torque_per_speed
# 0       10.5          0.027595
# ...

# %%
data=data.drop("Product ID", axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = data.select_dtypes(include=['number']).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap (Numeric Columns Only)")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x=data.drop("Failure Type",axis=1)
y=data["Failure Type"]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#        UDI  Type  Air temperature [K]  Process temperature [K]  \
# 6777  6778     1                301.2                    310.7
# 5855  5856     2                301.2                    310.9
# 4982  4983     1                303.7                    313.0
# 8441  8442     1                298.6                    309.9
# 8365  8366     2                298.8                    309.8
# ...    ...   ...                  ...                      ...
# 5782  5783     1                301.7                    311.1
# 5234  5235     1                303.7                    312.9
# 5435  5436     2                303.0                    312.5
# 866    867     1                295.9                    306.6
# 7326  7327     2                299.9                    310.5
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  temp_diff  \
# 6777                    1951         21.3               44       0        9.5
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9944640161046804

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                            precision    recall  f1-score   support
#
# Heat Dissipation Failure       0.95      1.00      0.98        20
#               No Failure       1.00      1.00      1.00      1927
#       Overstrain Failure       0.85      0.79      0.81        14
#            Power Failure       1.00      0.85      0.92        13
#          Random Failures       0.00      0.00      0.00         4
#        Tool Wear Failure       0.67      0.89      0.76         9
#
#                 accuracy                           0.99      1987
#                macro avg       0.74      0.75      0.74      1987
#             weighted avg       0.99      0.99      0.99      1987
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %%
cm
# Out:
# array([[  20,    0,    0,    0,    0,    0],
#        [   0, 1926,    0,    0,    0,    1],
#        [   0,    0,   11,    0,    0,    3],
#        [   1,    0,    1,   11,    0,    0],
#        [   0,    4,    0,    0,    0,    0],
#        [   0,    0,    1,    0,    0,    8]])

# %%
feat_imp = pd.Series(model.feature_importances_, index=x.columns).sort_values(ascending=False)
plt.figure(figsize=(10,5))
sns.barplot(x=feat_imp, y=feat_imp.index)
plt.title("Feature Importance")
plt.show()
